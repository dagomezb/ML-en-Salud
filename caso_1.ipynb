# %% [markdown]
# <a href="https://colab.research.google.com/github/dagomezb/ML-en-Salud/blob/main/caso_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Nuestros objetivos:
#
# *   Aprender a preparar datos y visualizarlos.
# *   Entender diferentes algoritmos de Machine Learning

# %% [markdown]
# **Terminología**
#
# * **Datos:** unidades de información o "hechos" de observaciones.
# * **Features:** tipos de información acerca de las observaciones.
# * **Filas:** observaciones individuales o muestras.
# * **Columnas:** features que describen las observaciones.
# * **Outlier:** punto(s) que se comportan de forma extraña.
# * **Pre-processing:** preparar datos para su uso en un modelo de Machine Learning.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ¿Qué es Machine Learning?
#
# Machine Learning es la ciencia de usar algoritmos para identificar patrones en datos con el fin de resolver un problema de interés.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # TIPOS DE MODELOS DE MACHINE LEARNING

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Aprendizaje Supervisado
#
# El modelo obtiene features de entrada y salida. Hay un target/objetivo a predecir.
#
# * **Regresión:** Target output es numérico.
# * **Clasificación:** Target output es una etiqueta

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Aprendizaje No Supervisado
#
# Objetivo desconocido. Queremos encontrar estructura y grupos dentro de los datos.
#
# * **Clustering:** Queremos encontrar grupos en los datos.
# * **Dimensionality reduction:** Queremos encontrar qué features de entrada en los datos son de ayuda.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Algorítmos Específicos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Hasta ahora ...
#
# * Algoritmos de Machine Learning generalmente son **supervisados** y **no supervisados**
#
# * Algoritmos supervisados generalmente predicen un objetivo o target. Pueden ser de regresión o clasificación.
#
# * Algoritmos no supervisados predicen patrones o estructura en los datos. Generalmente son de clustering o reducción de la dimensionalidad.

# %% [markdown]
# **Conclusiones**
#
# *   Modelos de ML encuentran patrones en los datos para resolver problemas.
# *   Los modelos aprenden patrones de los features.
# *   Machine Learning (ML) es un campo en crecimiento

# %% [markdown]
# # Receta de algoritmos ML
#
# * **Proceso de decisión:** cómo los modelos hacen una predicción, o retornan una respuesta, usando los parametros.
# * **Función de error / coste:** cómo evaluar si los parámetros en el modelo generan buenas predicciones.
# * **Regla de actualización:** cómo mejorar los parametros para hacer mejores predicciones (usando optimización numérica)

# %% [markdown]
# # Normalizar los datos numéricos
#
# Para cada columna del dataset con valores numéricos:
#
# 1. Calcular el promedio de los datos 𝜇.
# 2. Calcular la desviación estándar de los datos σ.
# 3. Para cada punto de datos:
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Preparar los Datos para los Modelos
#
# ![image.png](data:image/png;base64,...)
#
# * **Training** (60-80%) datos de los que el modelo aprende patrones.
# * **Validation** (0-20%) datos que se usan para validar si el modelo aprende.
# * **Testing** (0-20%) datos que se apartan para revisar si el modelo es exitoso en la predicción.
